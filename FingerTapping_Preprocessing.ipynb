# %%
import os

input_folder = "E:/Wasif/PD Motor Feature Extraction/Task2_All/"
output_folder = "E:/Wasif/PD Motor Feature Extraction/Task2_15_resized/"

# %%
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %% [markdown]
# ## Convert to 15 FPS

# %% [raw]
# files = os.listdir(input_folder)
# for f in files:
#     if ".webm" not in f:
#         continue
#     input_file = input_folder+f
#     output_file = output_folder+f[0:-5]+"-temp.webm"
#
#     command = "ffmpeg -y -r 15 -i \"%s\" \"%s\""%(input_file, output_file)
#     out = os.system(command)
#     print(out)

# %% [markdown]
# ## Convert webm to (256x256) and mp4

# %% [raw]
# import os
#
# input_folder = "E:/Wasif/PD Motor Feature Extraction/Task2_15_resized/"
# output_folder = "E:/Wasif/PD Motor Feature Extraction/Task2_15_resized_mp4/"
#
# files = os.listdir(input_folder)
# for f in files:
#     if ".webm" not in f:
#         continue
#     input_file = input_folder+f
#     output_file = output_folder+f[0:-5]+".mp4"
#     #output_file = output_folder+f
#     print(input_file)
#     print(output_file)
#
#     #command: ffmpeg -i video.webm -c:v copy video.mp4
#
#     command = "ffmpeg -i \"%s\" -vf scale=256:256 \"%s\""%(input_file, output_file)
#     out = os.system(command)
#     print(out)

# %% [raw]
# ##Get size and fps
# import cv2
# vcap = cv2.VideoCapture('E:/Wasif/PD Motor Feature Extraction/Task2_15_resized_mp4/2017-08-18T14-59-52-530Z49-task2-temp.webm')
# width = vcap.get(cv2.CAP_PROP_FRAME_WIDTH )
# height = vcap.get(cv2.CAP_PROP_FRAME_HEIGHT )
# fps =  vcap.get(cv2.CAP_PROP_FPS)

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\envs\park_motor\lib\site-packages\keras\__init__.py in <module>
#       2 try:
# ----> 3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-88d96843a926> in <module>
# ----> 1 import keras
#
# ~\Anaconda3\envs\park_motor\lib\site-packages\keras\__init__.py in <module>
#       3     from tensorflow.keras.layers.experimental.preprocessing import RandomRotation
#       4 except ImportError:
# ----> 5     raise ImportError(
#       6         'Keras requires TensorFlow 2.2 or higher. '
#       7         'Install TensorFlow via `pip install tensorflow`')
#
# ImportError: Keras requires TensorFlow 2.2 or higher. Install TensorFlow via `pip install tensorflow`

# %% [markdown]
# # Background removal

# %%
import pixellib
from pixellib.tune_bg import alter_bg

change_bg = alter_bg(model_type = "pb")
change_bg.load_pascalvoc_model("xception_pascalvoc.pb")
change_bg.color_video("sample_in.mp4", colors = (255,255,255), frames_per_second=15, output_video_name="sample_out.mp4", 
 detect = "person")
# Out:
# No. of frames: 1
# No. of frames: 2
# No. of frames: 3
# No. of frames: 4
# No. of frames: 5
# No. of frames: 6
# No. of frames: 7
# No. of frames: 8
# No. of frames: 9
# No. of frames: 10
# No. of frames: 11
# No. of frames: 12
# No. of frames: 13
# No. of frames: 14
# No. of frames: 15
# No. of frames: 16
# No. of frames: 17
# No. of frames: 18
# No. of frames: 19
# No. of frames: 20
# No. of frames: 21
# No. of frames: 22
# No. of frames: 23
# No. of frames: 24
# No. of frames: 25
# No. of frames: 26
# No. of frames: 27
# No. of frames: 28
